# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data
mnist = input_data.read_data_sets('./MNIST_data/')
# Out:
# WARNING:tensorflow:From <ipython-input-2-39fa257463af>:2: read_data_sets (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:260: maybe_download (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please write your own downloading logic.
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:252: _internal_retry.<locals>.wrap.<locals>.wrapped_fn (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use urllib or similar directly.
# Successfully downloaded train-images-idx3-ubyte.gz 9912422 bytes.
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST_data/train-images-idx3-ubyte.gz
# Successfully downloaded train-labels-idx1-ubyte.gz 28881 bytes.
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting ./MNIST_data/train-labels-idx1-ubyte.gz
# Successfully downloaded t10k-images-idx3-ubyte.gz 1648877 bytes.
# Extracting ./MNIST_data/t10k-images-idx3-ubyte.gz
# Successfully downloaded t10k-labels-idx1-ubyte.gz 4542 bytes.
# Extracting ./MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/contrib/learn/python/learn/datasets/mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
img = mnist.train.images[50]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %%
def get_inputs(real_size, noise_size):
    """
    真实图像tensor与噪声图像tensor
    """
    real_img = tf.placeholder(tf.float32, [None, real_size], name='real_img')
    noise_img = tf.placeholder(tf.float32, [None, noise_size], name='noise_img')
    
    return real_img, noise_img

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
    """
    生成器
    
    noise_img: 生成器的输入
    n_units: 隐层单元个数
    out_dim: 生成器输出tensor的size，这里应该为32*32=784
    alpha: leaky ReLU系数
    """
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):
    """
    判别器
    
    n_units: 隐层结点数量
    alpha: Leaky ReLU系数
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %%
# 定义参数
img_size = mnist.train.images[0].shape[0]
noise_size = 100
g_units = 128
d_units = 128
alpha = 0.01
learning_rate = 0.001
smooth = 0.1

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)
# Out:
# WARNING:tensorflow:From <ipython-input-5-61f994bd1269>:12: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-5-61f994bd1269>:16: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
# discriminator的loss
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)) * (1 - smooth))

d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)) * (1 - smooth))

# %%
train_vars = tf.trainable_variables()

# generator中的tensor
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator中的tensor
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
# batch_size
batch_size = 64
epochs = 300
n_sample = 25

samples = []
losses = []
saver = tf.train.Saver(var_list = g_vars)
# start training
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            batch_images = batch_images*2 - 1
            
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}(Real: {:.4f} + Fake: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        saver.save(sess, './checkpoints/generator.ckpt')

with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.0593(Real: 0.0173 + Fake: 0.0420)... Generator Loss: 4.0975
# Epoch 2/300... Discriminator Loss: 0.2989(Real: 0.0528 + Fake: 0.2460)... Generator Loss: 3.9485
# Epoch 3/300... Discriminator Loss: 1.2100(Real: 0.6077 + Fake: 0.6022)... Generator Loss: 2.8302
# Epoch 4/300... Discriminator Loss: 2.2107(Real: 0.4915 + Fake: 1.7192)... Generator Loss: 1.8411
# Epoch 5/300... Discriminator Loss: 0.6965(Real: 0.5105 + Fake: 0.1860)... Generator Loss: 2.1732
# Epoch 6/300... Discriminator Loss: 0.6768(Real: 0.3907 + Fake: 0.2861)... Generator Loss: 1.8644
# Epoch 7/300... Discriminator Loss: 1.5540(Real: 0.8471 + Fake: 0.7069)... Generator Loss: 2.3106
# Epoch 8/300... Discriminator Loss: 1.4134(Real: 0.9133 + Fake: 0.5001)... Generator Loss: 1.4757
# Epoch 9/300... Discriminator Loss: 0.9368(Real: 0.5139 + Fake: 0.4229)... Generator Loss: 1.6295
# Epoch 10/300... Discriminator Loss: 1.4287(Real: 0.8799 + Fake: 0.5487)... Generator Loss: 1.7446
# Epoch 11/300... Discriminator Loss: 0.7265(Real: 0.4767 + Fake: 0.2499)... Generator Loss: 1.9865
# Epoch 12/300... Discriminator Loss: 1.0532(Real: 0.3058 + Fake: 0.7475)... Generator Loss: 1.4522
# Epoch 13/300... Discriminator Loss: 1.3739(Real: 0.6256 + Fake: 0.7483)... Generator Loss: 1.2360
# Epoch 14/300... Discriminator Loss: 1.3520(Real: 0.9021 + Fake: 0.4499)... Generator Loss: 1.3324
# Epoch 15/300... Discriminator Loss: 1.2103(Real: 0.8738 + Fake: 0.3365)... Generator Loss: 2.2031
# Epoch 16/300... Discriminator Loss: 0.7460(Real: 0.3778 + Fake: 0.3682)... Generator Loss: 1.3369
# Epoch 17/300... Discriminator Loss: 0.9638(Real: 0.6313 + Fake: 0.3326)... Generator Loss: 1.5141
# Epoch 18/300... Discriminator Loss: 1.1545(Real: 0.7410 + Fake: 0.4135)... Generator Loss: 1.7872
# Epoch 19/300... Discriminator Loss: 1.1408(Real: 0.4621 + Fake: 0.6787)... Generator Loss: 1.3866
# Epoch 20/300... Discriminator Loss: 1.1914(Real: 0.4985 + Fake: 0.6929)... Generator Loss: 1.1049
# Epoch 21/300... Discriminator Loss: 1.1348(Real: 0.4460 + Fake: 0.6889)... Generator Loss: 0.9899
# Epoch 22/300... Discriminator Loss: 1.1104(Real: 0.3676 + Fake: 0.7428)... Generator Loss: 1.0544
# Epoch 23/300... Discriminator Loss: 0.8850(Real: 0.5169 + Fake: 0.3681)... Generator Loss: 1.6104
# Epoch 24/300... Discriminator Loss: 1.2651(Real: 0.7217 + Fake: 0.5434)... Generator Loss: 1.2142
# Epoch 25/300... Discriminator Loss: 1.3118(Real: 0.6472 + Fake: 0.6646)... Generator Loss: 1.1219
# Epoch 26/300... Discriminator Loss: 1.1706(Real: 0.5572 + Fake: 0.6134)... Generator Loss: 1.1279
# Epoch 27/300... Discriminator Loss: 1.0488(Real: 0.5195 + Fake: 0.5293)... Generator Loss: 1.1256
# Epoch 28/300... Discriminator Loss: 1.1279(Real: 0.5396 + Fake: 0.5883)... Generator Loss: 1.7430
# Epoch 29/300... Discriminator Loss: 1.0429(Real: 0.7774 + Fake: 0.2655)... Generator Loss: 1.9156
# Epoch 30/300... Discriminator Loss: 1.2562(Real: 0.7843 + Fake: 0.4720)... Generator Loss: 1.4618
# Epoch 31/300... Discriminator Loss: 1.1978(Real: 0.5164 + Fake: 0.6814)... Generator Loss: 1.0661
# Epoch 32/300... Discriminator Loss: 0.9427(Real: 0.4756 + Fake: 0.4672)... Generator Loss: 1.3729
# Epoch 33/300... Discriminator Loss: 1.1062(Real: 0.6521 + Fake: 0.4541)... Generator Loss: 1.7075
# Epoch 34/300... Discriminator Loss: 0.9267(Real: 0.5820 + Fake: 0.3447)... Generator Loss: 1.8305
# Epoch 35/300... Discriminator Loss: 1.1403(Real: 0.4490 + Fake: 0.6912)... Generator Loss: 1.0466
# Epoch 36/300... Discriminator Loss: 0.8715(Real: 0.4583 + Fake: 0.4131)... Generator Loss: 1.8064
# Epoch 37/300... Discriminator Loss: 0.9477(Real: 0.5742 + Fake: 0.3735)... Generator Loss: 1.3799
# Epoch 38/300... Discriminator Loss: 1.0052(Real: 0.4511 + Fake: 0.5541)... Generator Loss: 1.6737
# Epoch 39/300... Discriminator Loss: 0.9135(Real: 0.4254 + Fake: 0.4881)... Generator Loss: 1.4875
# Epoch 40/300... Discriminator Loss: 0.7170(Real: 0.4727 + Fake: 0.2443)... Generator Loss: 1.9492
# Epoch 41/300... Discriminator Loss: 0.8391(Real: 0.1850 + Fake: 0.6541)... Generator Loss: 1.2711
# Epoch 42/300... Discriminator Loss: 0.6331(Real: 0.3371 + Fake: 0.2960)... Generator Loss: 1.8099
# Epoch 43/300... Discriminator Loss: 0.9037(Real: 0.3567 + Fake: 0.5469)... Generator Loss: 1.0584
# Epoch 44/300... Discriminator Loss: 0.9037(Real: 0.3845 + Fake: 0.5192)... Generator Loss: 1.3212
# Epoch 45/300... Discriminator Loss: 0.8859(Real: 0.4569 + Fake: 0.4290)... Generator Loss: 1.4649
# Epoch 46/300... Discriminator Loss: 0.8096(Real: 0.4413 + Fake: 0.3683)... Generator Loss: 1.5570
# Epoch 47/300... Discriminator Loss: 1.3731(Real: 0.6365 + Fake: 0.7366)... Generator Loss: 1.1307
# Epoch 48/300... Discriminator Loss: 0.6637(Real: 0.2097 + Fake: 0.4540)... Generator Loss: 1.3140
# Epoch 49/300... Discriminator Loss: 1.3305(Real: 0.8749 + Fake: 0.4556)... Generator Loss: 1.4665
# Epoch 50/300... Discriminator Loss: 0.8477(Real: 0.4231 + Fake: 0.4246)... Generator Loss: 1.4791
# Epoch 51/300... Discriminator Loss: 0.8655(Real: 0.3789 + Fake: 0.4866)... Generator Loss: 1.1561
# Epoch 52/300... Discriminator Loss: 0.9642(Real: 0.5691 + Fake: 0.3951)... Generator Loss: 1.4927
# Epoch 53/300... Discriminator Loss: 0.7282(Real: 0.4065 + Fake: 0.3217)... Generator Loss: 1.6263
# Epoch 54/300... Discriminator Loss: 0.8338(Real: 0.4352 + Fake: 0.3986)... Generator Loss: 1.6688
# Epoch 55/300... Discriminator Loss: 1.0709(Real: 0.6124 + Fake: 0.4585)... Generator Loss: 1.2358
# Epoch 56/300... Discriminator Loss: 1.0000(Real: 0.5550 + Fake: 0.4450)... Generator Loss: 1.4043
# Epoch 57/300... Discriminator Loss: 0.7358(Real: 0.4011 + Fake: 0.3346)... Generator Loss: 1.7072
# Epoch 58/300... Discriminator Loss: 1.2315(Real: 0.5362 + Fake: 0.6953)... Generator Loss: 1.0939
# Epoch 59/300... Discriminator Loss: 1.3740(Real: 0.8146 + Fake: 0.5594)... Generator Loss: 1.2140
# Epoch 60/300... Discriminator Loss: 0.8986(Real: 0.3763 + Fake: 0.5224)... Generator Loss: 1.1297
# Epoch 61/300... Discriminator Loss: 0.7322(Real: 0.3898 + Fake: 0.3424)... Generator Loss: 1.6209
# Epoch 62/300... Discriminator Loss: 1.0036(Real: 0.5536 + Fake: 0.4500)... Generator Loss: 1.4578
# Epoch 63/300... Discriminator Loss: 0.9756(Real: 0.4670 + Fake: 0.5086)... Generator Loss: 1.3325
# Epoch 64/300... Discriminator Loss: 1.0512(Real: 0.4926 + Fake: 0.5586)... Generator Loss: 1.3016
# Epoch 65/300... Discriminator Loss: 1.1416(Real: 0.4467 + Fake: 0.6948)... Generator Loss: 0.9703
# Epoch 66/300... Discriminator Loss: 0.6205(Real: 0.2936 + Fake: 0.3269)... Generator Loss: 1.6756
# Epoch 67/300... Discriminator Loss: 1.0345(Real: 0.7227 + Fake: 0.3117)... Generator Loss: 1.6927
# Epoch 68/300... Discriminator Loss: 0.9736(Real: 0.4341 + Fake: 0.5395)... Generator Loss: 1.2110
# Epoch 69/300... Discriminator Loss: 0.8541(Real: 0.4003 + Fake: 0.4538)... Generator Loss: 1.4605
# Epoch 70/300... Discriminator Loss: 1.0347(Real: 0.5543 + Fake: 0.4804)... Generator Loss: 1.3237
# Epoch 71/300... Discriminator Loss: 0.9820(Real: 0.4424 + Fake: 0.5396)... Generator Loss: 1.3611
# Epoch 72/300... Discriminator Loss: 0.7316(Real: 0.4237 + Fake: 0.3079)... Generator Loss: 1.7600
# Epoch 73/300... Discriminator Loss: 0.9654(Real: 0.4113 + Fake: 0.5540)... Generator Loss: 1.2752
# Epoch 74/300... Discriminator Loss: 0.8748(Real: 0.4833 + Fake: 0.3916)... Generator Loss: 1.5708
# Epoch 75/300... Discriminator Loss: 1.2057(Real: 0.6278 + Fake: 0.5779)... Generator Loss: 1.0775
# Epoch 76/300... Discriminator Loss: 0.9375(Real: 0.5295 + Fake: 0.4080)... Generator Loss: 1.4779
# Epoch 77/300... Discriminator Loss: 0.8319(Real: 0.5390 + Fake: 0.2929)... Generator Loss: 1.6356
# Epoch 78/300... Discriminator Loss: 0.9536(Real: 0.3877 + Fake: 0.5659)... Generator Loss: 1.1498
# Epoch 79/300... Discriminator Loss: 0.9738(Real: 0.4274 + Fake: 0.5464)... Generator Loss: 1.2861
# Epoch 80/300... Discriminator Loss: 0.9369(Real: 0.4984 + Fake: 0.4385)... Generator Loss: 1.3021
# Epoch 81/300... Discriminator Loss: 0.9215(Real: 0.4688 + Fake: 0.4527)... Generator Loss: 1.3771
# Epoch 82/300... Discriminator Loss: 1.0462(Real: 0.4647 + Fake: 0.5815)... Generator Loss: 1.1445
# Epoch 83/300... Discriminator Loss: 1.0752(Real: 0.4697 + Fake: 0.6055)... Generator Loss: 1.1071
# Epoch 84/300... Discriminator Loss: 1.0023(Real: 0.5458 + Fake: 0.4565)... Generator Loss: 1.3269
# Epoch 85/300... Discriminator Loss: 0.8389(Real: 0.3421 + Fake: 0.4968)... Generator Loss: 1.3853
# Epoch 86/300... Discriminator Loss: 0.8858(Real: 0.5018 + Fake: 0.3840)... Generator Loss: 1.4091
# Epoch 87/300... Discriminator Loss: 1.0204(Real: 0.6456 + Fake: 0.3748)... Generator Loss: 1.3949
# Epoch 88/300... Discriminator Loss: 1.1712(Real: 0.7717 + Fake: 0.3995)... Generator Loss: 1.5950
# Epoch 89/300... Discriminator Loss: 1.1330(Real: 0.6125 + Fake: 0.5205)... Generator Loss: 1.1917
# Epoch 90/300... Discriminator Loss: 0.9153(Real: 0.5058 + Fake: 0.4095)... Generator Loss: 1.4770
# Epoch 91/300... Discriminator Loss: 0.9008(Real: 0.5179 + Fake: 0.3829)... Generator Loss: 1.5436
# Epoch 92/300... Discriminator Loss: 0.8620(Real: 0.5385 + Fake: 0.3235)... Generator Loss: 1.6544
# Epoch 93/300... Discriminator Loss: 1.0748(Real: 0.5742 + Fake: 0.5006)... Generator Loss: 1.2785
# Epoch 94/300... Discriminator Loss: 0.8838(Real: 0.3741 + Fake: 0.5096)... Generator Loss: 1.2940
# Epoch 95/300... Discriminator Loss: 1.0881(Real: 0.4065 + Fake: 0.6815)... Generator Loss: 0.9660
# Epoch 96/300... Discriminator Loss: 0.9831(Real: 0.3297 + Fake: 0.6535)... Generator Loss: 1.0343
# Epoch 97/300... Discriminator Loss: 0.7633(Real: 0.4036 + Fake: 0.3597)... Generator Loss: 1.4539
# Epoch 98/300... Discriminator Loss: 0.8662(Real: 0.4736 + Fake: 0.3926)... Generator Loss: 1.3610
# Epoch 99/300... Discriminator Loss: 0.9198(Real: 0.3384 + Fake: 0.5814)... Generator Loss: 1.1438
# Epoch 100/300... Discriminator Loss: 0.9695(Real: 0.5566 + Fake: 0.4129)... Generator Loss: 1.4346
# Epoch 101/300... Discriminator Loss: 0.9226(Real: 0.3892 + Fake: 0.5335)... Generator Loss: 1.3452
# Epoch 102/300... Discriminator Loss: 1.0057(Real: 0.5015 + Fake: 0.5042)... Generator Loss: 1.3495
# Epoch 103/300... Discriminator Loss: 1.0104(Real: 0.4299 + Fake: 0.5806)... Generator Loss: 1.1700
# Epoch 104/300... Discriminator Loss: 0.8991(Real: 0.5387 + Fake: 0.3604)... Generator Loss: 1.6196
# Epoch 105/300... Discriminator Loss: 1.0038(Real: 0.4666 + Fake: 0.5372)... Generator Loss: 1.2171
# Epoch 106/300... Discriminator Loss: 0.9904(Real: 0.5223 + Fake: 0.4681)... Generator Loss: 1.3043
# Epoch 107/300... Discriminator Loss: 0.8171(Real: 0.3506 + Fake: 0.4665)... Generator Loss: 1.3935
# Epoch 108/300... Discriminator Loss: 0.9999(Real: 0.4487 + Fake: 0.5512)... Generator Loss: 1.1548
# Epoch 109/300... Discriminator Loss: 0.9735(Real: 0.4345 + Fake: 0.5390)... Generator Loss: 1.2311
# Epoch 110/300... Discriminator Loss: 0.7578(Real: 0.3668 + Fake: 0.3910)... Generator Loss: 1.4721
# Epoch 111/300... Discriminator Loss: 1.2057(Real: 0.6586 + Fake: 0.5471)... Generator Loss: 1.3574
# Epoch 112/300... Discriminator Loss: 1.0487(Real: 0.6320 + Fake: 0.4167)... Generator Loss: 1.5409
# Epoch 113/300... Discriminator Loss: 0.9983(Real: 0.5080 + Fake: 0.4903)... Generator Loss: 1.2473
# Epoch 114/300... Discriminator Loss: 0.8790(Real: 0.4713 + Fake: 0.4077)... Generator Loss: 1.4692
# Epoch 115/300... Discriminator Loss: 0.8791(Real: 0.4771 + Fake: 0.4020)... Generator Loss: 1.4430
# Epoch 116/300... Discriminator Loss: 0.9859(Real: 0.4997 + Fake: 0.4862)... Generator Loss: 1.2482
# Epoch 117/300... Discriminator Loss: 0.9459(Real: 0.4609 + Fake: 0.4850)... Generator Loss: 1.3546
# Epoch 118/300... Discriminator Loss: 0.8492(Real: 0.4272 + Fake: 0.4220)... Generator Loss: 1.4503
# Epoch 119/300... Discriminator Loss: 0.8163(Real: 0.3715 + Fake: 0.4448)... Generator Loss: 1.3405
# Epoch 120/300... Discriminator Loss: 0.9133(Real: 0.3821 + Fake: 0.5312)... Generator Loss: 1.3392
# Epoch 121/300... Discriminator Loss: 0.8684(Real: 0.3225 + Fake: 0.5459)... Generator Loss: 1.2709
# Epoch 122/300... Discriminator Loss: 0.9359(Real: 0.4271 + Fake: 0.5088)... Generator Loss: 1.2969
# Epoch 123/300... Discriminator Loss: 0.7873(Real: 0.4703 + Fake: 0.3169)... Generator Loss: 1.6059
# Epoch 124/300... Discriminator Loss: 0.8072(Real: 0.4066 + Fake: 0.4005)... Generator Loss: 1.4396
# Epoch 125/300... Discriminator Loss: 0.9204(Real: 0.4715 + Fake: 0.4489)... Generator Loss: 1.5331
# Epoch 126/300... Discriminator Loss: 0.8614(Real: 0.5087 + Fake: 0.3527)... Generator Loss: 1.4985
# Epoch 127/300... Discriminator Loss: 0.9645(Real: 0.6159 + Fake: 0.3485)... Generator Loss: 1.6251
# Epoch 128/300... Discriminator Loss: 1.0351(Real: 0.5444 + Fake: 0.4907)... Generator Loss: 1.2942
# Epoch 129/300... Discriminator Loss: 0.9398(Real: 0.5118 + Fake: 0.4280)... Generator Loss: 1.4530
# Epoch 130/300... Discriminator Loss: 0.8750(Real: 0.4852 + Fake: 0.3897)... Generator Loss: 1.5846
# Epoch 131/300... Discriminator Loss: 0.8506(Real: 0.5167 + Fake: 0.3339)... Generator Loss: 1.7367
# Epoch 132/300... Discriminator Loss: 0.9260(Real: 0.4178 + Fake: 0.5082)... Generator Loss: 1.4318
# Epoch 133/300... Discriminator Loss: 0.8264(Real: 0.4715 + Fake: 0.3549)... Generator Loss: 1.5733
# Epoch 134/300... Discriminator Loss: 0.9378(Real: 0.4564 + Fake: 0.4815)... Generator Loss: 1.3335
# Epoch 135/300... Discriminator Loss: 0.9310(Real: 0.6052 + Fake: 0.3257)... Generator Loss: 1.6215
# Epoch 136/300... Discriminator Loss: 0.9723(Real: 0.6805 + Fake: 0.2918)... Generator Loss: 1.7773
# Epoch 137/300... Discriminator Loss: 0.8023(Real: 0.4200 + Fake: 0.3823)... Generator Loss: 1.5415
# Epoch 138/300... Discriminator Loss: 1.0078(Real: 0.5082 + Fake: 0.4996)... Generator Loss: 1.3695
# Epoch 139/300... Discriminator Loss: 1.0806(Real: 0.5865 + Fake: 0.4941)... Generator Loss: 1.3218
# Epoch 140/300... Discriminator Loss: 0.9997(Real: 0.4346 + Fake: 0.5651)... Generator Loss: 1.1905
# Epoch 141/300... Discriminator Loss: 0.9675(Real: 0.3461 + Fake: 0.6214)... Generator Loss: 1.2082
# Epoch 142/300... Discriminator Loss: 1.1922(Real: 0.6214 + Fake: 0.5708)... Generator Loss: 1.2207
# Epoch 143/300... Discriminator Loss: 0.8586(Real: 0.3107 + Fake: 0.5479)... Generator Loss: 1.3305
# Epoch 144/300... Discriminator Loss: 0.9570(Real: 0.4480 + Fake: 0.5091)... Generator Loss: 1.4113
# Epoch 145/300... Discriminator Loss: 0.9744(Real: 0.5271 + Fake: 0.4472)... Generator Loss: 1.4408
# Epoch 146/300... Discriminator Loss: 0.9020(Real: 0.4342 + Fake: 0.4678)... Generator Loss: 1.3857
# Epoch 147/300... Discriminator Loss: 0.8547(Real: 0.2999 + Fake: 0.5548)... Generator Loss: 1.3522
# Epoch 148/300... Discriminator Loss: 1.1105(Real: 0.6404 + Fake: 0.4702)... Generator Loss: 1.3860
# Epoch 149/300... Discriminator Loss: 0.8678(Real: 0.6207 + Fake: 0.2471)... Generator Loss: 2.0754
# Epoch 150/300... Discriminator Loss: 0.7425(Real: 0.2907 + Fake: 0.4518)... Generator Loss: 1.4132
# Epoch 151/300... Discriminator Loss: 1.0085(Real: 0.5150 + Fake: 0.4935)... Generator Loss: 1.5259
# Epoch 152/300... Discriminator Loss: 0.8208(Real: 0.4046 + Fake: 0.4162)... Generator Loss: 1.6558
# Epoch 153/300... Discriminator Loss: 0.9595(Real: 0.4215 + Fake: 0.5380)... Generator Loss: 1.2347
# Epoch 154/300... Discriminator Loss: 0.9727(Real: 0.5310 + Fake: 0.4416)... Generator Loss: 1.5254
# Epoch 155/300... Discriminator Loss: 1.0456(Real: 0.5112 + Fake: 0.5344)... Generator Loss: 1.2955
# Epoch 156/300... Discriminator Loss: 0.8971(Real: 0.3727 + Fake: 0.5244)... Generator Loss: 1.3012
# Epoch 157/300... Discriminator Loss: 0.8386(Real: 0.5134 + Fake: 0.3252)... Generator Loss: 1.6293
# Epoch 158/300... Discriminator Loss: 0.9543(Real: 0.5844 + Fake: 0.3700)... Generator Loss: 1.7375
# Epoch 159/300... Discriminator Loss: 0.6764(Real: 0.3393 + Fake: 0.3372)... Generator Loss: 1.6084
# Epoch 160/300... Discriminator Loss: 0.8766(Real: 0.3301 + Fake: 0.5465)... Generator Loss: 1.3112
# Epoch 161/300... Discriminator Loss: 0.8889(Real: 0.3681 + Fake: 0.5208)... Generator Loss: 1.2821
# Epoch 162/300... Discriminator Loss: 0.8616(Real: 0.4183 + Fake: 0.4433)... Generator Loss: 1.6816
# Epoch 163/300... Discriminator Loss: 0.8571(Real: 0.3550 + Fake: 0.5021)... Generator Loss: 1.5324
# Epoch 164/300... Discriminator Loss: 0.6689(Real: 0.2993 + Fake: 0.3696)... Generator Loss: 1.7073
# Epoch 165/300... Discriminator Loss: 0.9693(Real: 0.3606 + Fake: 0.6087)... Generator Loss: 1.4554
# Epoch 166/300... Discriminator Loss: 1.0347(Real: 0.3667 + Fake: 0.6680)... Generator Loss: 1.1989
# Epoch 167/300... Discriminator Loss: 0.8234(Real: 0.3782 + Fake: 0.4452)... Generator Loss: 1.7150
# Epoch 168/300... Discriminator Loss: 0.8310(Real: 0.4096 + Fake: 0.4214)... Generator Loss: 1.5791
# Epoch 169/300... Discriminator Loss: 0.9708(Real: 0.5680 + Fake: 0.4027)... Generator Loss: 1.5472
# Epoch 170/300... Discriminator Loss: 0.8522(Real: 0.3519 + Fake: 0.5002)... Generator Loss: 1.2939
# Epoch 171/300... Discriminator Loss: 0.7525(Real: 0.3628 + Fake: 0.3898)... Generator Loss: 1.7021
# Epoch 172/300... Discriminator Loss: 1.0124(Real: 0.4031 + Fake: 0.6093)... Generator Loss: 1.1685
# Epoch 173/300... Discriminator Loss: 0.8258(Real: 0.3630 + Fake: 0.4628)... Generator Loss: 1.5146
# Epoch 174/300... Discriminator Loss: 0.7928(Real: 0.3215 + Fake: 0.4713)... Generator Loss: 1.6304
# Epoch 175/300... Discriminator Loss: 0.9211(Real: 0.5086 + Fake: 0.4125)... Generator Loss: 1.6879
# Epoch 176/300... Discriminator Loss: 0.9774(Real: 0.4532 + Fake: 0.5242)... Generator Loss: 1.3963
# Epoch 177/300... Discriminator Loss: 0.8082(Real: 0.3961 + Fake: 0.4122)... Generator Loss: 1.6663
# Epoch 178/300... Discriminator Loss: 0.7639(Real: 0.4973 + Fake: 0.2666)... Generator Loss: 2.0503
# Epoch 179/300... Discriminator Loss: 0.7955(Real: 0.4803 + Fake: 0.3151)... Generator Loss: 1.7220
# Epoch 180/300... Discriminator Loss: 0.9420(Real: 0.5357 + Fake: 0.4063)... Generator Loss: 1.4815
# Epoch 181/300... Discriminator Loss: 0.8117(Real: 0.2682 + Fake: 0.5435)... Generator Loss: 1.3411
# Epoch 182/300... Discriminator Loss: 0.7579(Real: 0.3608 + Fake: 0.3971)... Generator Loss: 1.6250
# Epoch 183/300... Discriminator Loss: 0.8032(Real: 0.5103 + Fake: 0.2929)... Generator Loss: 1.8460
# Epoch 184/300... Discriminator Loss: 0.8827(Real: 0.5150 + Fake: 0.3677)... Generator Loss: 1.6838
# Epoch 185/300... Discriminator Loss: 0.8900(Real: 0.3810 + Fake: 0.5090)... Generator Loss: 1.3329
# Epoch 186/300... Discriminator Loss: 0.8817(Real: 0.4660 + Fake: 0.4157)... Generator Loss: 1.4588
# Epoch 187/300... Discriminator Loss: 0.8459(Real: 0.3058 + Fake: 0.5402)... Generator Loss: 1.4745
# Epoch 188/300... Discriminator Loss: 0.8794(Real: 0.6405 + Fake: 0.2389)... Generator Loss: 2.1789
# Epoch 189/300... Discriminator Loss: 0.7215(Real: 0.3013 + Fake: 0.4202)... Generator Loss: 1.5373
# Epoch 190/300... Discriminator Loss: 0.7700(Real: 0.3779 + Fake: 0.3921)... Generator Loss: 1.6605
# Epoch 191/300... Discriminator Loss: 0.7374(Real: 0.2264 + Fake: 0.5109)... Generator Loss: 1.4179
# Epoch 192/300... Discriminator Loss: 0.9056(Real: 0.3876 + Fake: 0.5180)... Generator Loss: 1.5446
# Epoch 193/300... Discriminator Loss: 0.8929(Real: 0.3985 + Fake: 0.4945)... Generator Loss: 1.4641
# Epoch 194/300... Discriminator Loss: 0.7986(Real: 0.3443 + Fake: 0.4543)... Generator Loss: 1.4855
# Epoch 195/300... Discriminator Loss: 0.7667(Real: 0.3205 + Fake: 0.4462)... Generator Loss: 1.5444
# Epoch 196/300... Discriminator Loss: 0.9377(Real: 0.5276 + Fake: 0.4102)... Generator Loss: 1.9328
# Epoch 197/300... Discriminator Loss: 0.9572(Real: 0.6888 + Fake: 0.2684)... Generator Loss: 2.0396
# Epoch 198/300... Discriminator Loss: 0.7146(Real: 0.3572 + Fake: 0.3574)... Generator Loss: 1.7487
# Epoch 199/300... Discriminator Loss: 0.8827(Real: 0.4379 + Fake: 0.4448)... Generator Loss: 1.4636
# Epoch 200/300... Discriminator Loss: 0.6913(Real: 0.3915 + Fake: 0.2998)... Generator Loss: 1.8715
# Epoch 201/300... Discriminator Loss: 0.9148(Real: 0.4765 + Fake: 0.4383)... Generator Loss: 1.7034
# Epoch 202/300... Discriminator Loss: 0.7850(Real: 0.2988 + Fake: 0.4862)... Generator Loss: 1.5059
# Epoch 203/300... Discriminator Loss: 0.6817(Real: 0.3278 + Fake: 0.3539)... Generator Loss: 1.5729
# Epoch 204/300... Discriminator Loss: 0.7356(Real: 0.4709 + Fake: 0.2647)... Generator Loss: 2.1524
# Epoch 205/300... Discriminator Loss: 0.7589(Real: 0.4152 + Fake: 0.3437)... Generator Loss: 1.7087
# Epoch 206/300... Discriminator Loss: 0.9098(Real: 0.2765 + Fake: 0.6333)... Generator Loss: 1.2809
# Epoch 207/300... Discriminator Loss: 0.9776(Real: 0.4575 + Fake: 0.5201)... Generator Loss: 1.4738
# Epoch 208/300... Discriminator Loss: 0.8969(Real: 0.4633 + Fake: 0.4335)... Generator Loss: 1.4765
# Epoch 209/300... Discriminator Loss: 0.7579(Real: 0.3538 + Fake: 0.4040)... Generator Loss: 1.7265
# Epoch 210/300... Discriminator Loss: 0.7388(Real: 0.3773 + Fake: 0.3616)... Generator Loss: 1.7267
# Epoch 211/300... Discriminator Loss: 0.8208(Real: 0.4203 + Fake: 0.4005)... Generator Loss: 1.5995
# Epoch 212/300... Discriminator Loss: 1.0693(Real: 0.5652 + Fake: 0.5042)... Generator Loss: 1.4843
# Epoch 213/300... Discriminator Loss: 0.8979(Real: 0.5017 + Fake: 0.3962)... Generator Loss: 1.7411
# Epoch 214/300... Discriminator Loss: 0.7585(Real: 0.4541 + Fake: 0.3044)... Generator Loss: 1.7053
# Epoch 215/300... Discriminator Loss: 0.7795(Real: 0.3898 + Fake: 0.3896)... Generator Loss: 1.7071
# Epoch 216/300... Discriminator Loss: 0.8360(Real: 0.4936 + Fake: 0.3424)... Generator Loss: 1.8247
# Epoch 217/300... Discriminator Loss: 0.7617(Real: 0.3972 + Fake: 0.3646)... Generator Loss: 1.5177
# Epoch 218/300... Discriminator Loss: 0.8328(Real: 0.3797 + Fake: 0.4531)... Generator Loss: 1.6227
# Epoch 219/300... Discriminator Loss: 0.7000(Real: 0.3001 + Fake: 0.3999)... Generator Loss: 1.7234
# Epoch 220/300... Discriminator Loss: 0.7857(Real: 0.4925 + Fake: 0.2932)... Generator Loss: 2.0087
# Epoch 221/300... Discriminator Loss: 1.0245(Real: 0.3446 + Fake: 0.6799)... Generator Loss: 1.2563
# Epoch 222/300... Discriminator Loss: 0.7866(Real: 0.4792 + Fake: 0.3074)... Generator Loss: 1.7873
# Epoch 223/300... Discriminator Loss: 0.8138(Real: 0.3640 + Fake: 0.4498)... Generator Loss: 1.8491
# Epoch 224/300... Discriminator Loss: 0.8781(Real: 0.5597 + Fake: 0.3184)... Generator Loss: 1.9028
# Epoch 225/300... Discriminator Loss: 0.8190(Real: 0.3959 + Fake: 0.4231)... Generator Loss: 1.5964
# Epoch 226/300... Discriminator Loss: 0.8524(Real: 0.4245 + Fake: 0.4279)... Generator Loss: 1.4966
# Epoch 227/300... Discriminator Loss: 0.7919(Real: 0.5054 + Fake: 0.2865)... Generator Loss: 2.3719
# Epoch 228/300... Discriminator Loss: 0.7870(Real: 0.2738 + Fake: 0.5132)... Generator Loss: 1.3345
# Epoch 229/300... Discriminator Loss: 0.7582(Real: 0.3983 + Fake: 0.3599)... Generator Loss: 1.8078
# Epoch 230/300... Discriminator Loss: 0.6243(Real: 0.2817 + Fake: 0.3425)... Generator Loss: 1.7635
# Epoch 231/300... Discriminator Loss: 0.8788(Real: 0.4599 + Fake: 0.4189)... Generator Loss: 1.4668
# Epoch 232/300... Discriminator Loss: 0.8932(Real: 0.3355 + Fake: 0.5577)... Generator Loss: 1.5719
# Epoch 233/300... Discriminator Loss: 0.9197(Real: 0.5168 + Fake: 0.4029)... Generator Loss: 1.6853
# Epoch 234/300... Discriminator Loss: 0.7998(Real: 0.3326 + Fake: 0.4671)... Generator Loss: 1.6467
# Epoch 235/300... Discriminator Loss: 0.7350(Real: 0.3426 + Fake: 0.3924)... Generator Loss: 1.7299
# Epoch 236/300... Discriminator Loss: 0.9249(Real: 0.4228 + Fake: 0.5021)... Generator Loss: 1.5466
# Epoch 237/300... Discriminator Loss: 0.8489(Real: 0.3638 + Fake: 0.4851)... Generator Loss: 1.7235
# Epoch 238/300... Discriminator Loss: 0.7780(Real: 0.4113 + Fake: 0.3667)... Generator Loss: 1.7681
# Epoch 239/300... Discriminator Loss: 0.9436(Real: 0.5842 + Fake: 0.3595)... Generator Loss: 1.9376
# Epoch 240/300... Discriminator Loss: 0.9857(Real: 0.4880 + Fake: 0.4977)... Generator Loss: 1.4616
# Epoch 241/300... Discriminator Loss: 0.8890(Real: 0.5556 + Fake: 0.3334)... Generator Loss: 1.8287
# Epoch 242/300... Discriminator Loss: 0.8362(Real: 0.4278 + Fake: 0.4084)... Generator Loss: 1.6044
# Epoch 243/300... Discriminator Loss: 0.7582(Real: 0.2293 + Fake: 0.5289)... Generator Loss: 1.2671
# Epoch 244/300... Discriminator Loss: 0.6690(Real: 0.3135 + Fake: 0.3555)... Generator Loss: 1.7247
# Epoch 245/300... Discriminator Loss: 0.9797(Real: 0.5239 + Fake: 0.4558)... Generator Loss: 1.5768
# Epoch 246/300... Discriminator Loss: 0.8544(Real: 0.2790 + Fake: 0.5754)... Generator Loss: 1.5216
# Epoch 247/300... Discriminator Loss: 0.7402(Real: 0.3975 + Fake: 0.3428)... Generator Loss: 1.8555
# Epoch 248/300... Discriminator Loss: 0.7107(Real: 0.3832 + Fake: 0.3275)... Generator Loss: 1.7407
# Epoch 249/300... Discriminator Loss: 0.7571(Real: 0.3440 + Fake: 0.4130)... Generator Loss: 1.6622
# Epoch 250/300... Discriminator Loss: 0.6485(Real: 0.3155 + Fake: 0.3330)... Generator Loss: 1.7503
# Epoch 251/300... Discriminator Loss: 0.8872(Real: 0.6012 + Fake: 0.2860)... Generator Loss: 2.2294
# Epoch 252/300... Discriminator Loss: 0.8023(Real: 0.4744 + Fake: 0.3279)... Generator Loss: 1.9526
# Epoch 253/300... Discriminator Loss: 0.9052(Real: 0.5922 + Fake: 0.3130)... Generator Loss: 2.0326
# Epoch 254/300... Discriminator Loss: 0.8669(Real: 0.5420 + Fake: 0.3250)... Generator Loss: 1.7017
# Epoch 255/300... Discriminator Loss: 0.7752(Real: 0.4323 + Fake: 0.3429)... Generator Loss: 1.7581
# Epoch 256/300... Discriminator Loss: 0.9627(Real: 0.5658 + Fake: 0.3969)... Generator Loss: 1.6628
# Epoch 257/300... Discriminator Loss: 0.7292(Real: 0.3622 + Fake: 0.3669)... Generator Loss: 1.6849
# Epoch 258/300... Discriminator Loss: 0.7119(Real: 0.3587 + Fake: 0.3532)... Generator Loss: 1.7461
# Epoch 259/300... Discriminator Loss: 0.6370(Real: 0.3309 + Fake: 0.3061)... Generator Loss: 1.8982
# Epoch 260/300... Discriminator Loss: 0.7994(Real: 0.4067 + Fake: 0.3928)... Generator Loss: 1.7135
# Epoch 261/300... Discriminator Loss: 0.7660(Real: 0.5687 + Fake: 0.1973)... Generator Loss: 2.2608
# Epoch 262/300... Discriminator Loss: 0.9242(Real: 0.5383 + Fake: 0.3858)... Generator Loss: 1.6677
# Epoch 263/300... Discriminator Loss: 0.8039(Real: 0.3035 + Fake: 0.5005)... Generator Loss: 1.3748
# Epoch 264/300... Discriminator Loss: 0.7807(Real: 0.4253 + Fake: 0.3554)... Generator Loss: 1.9184
# Epoch 265/300... Discriminator Loss: 0.9455(Real: 0.3563 + Fake: 0.5893)... Generator Loss: 1.2419
# Epoch 266/300... Discriminator Loss: 0.6350(Real: 0.3180 + Fake: 0.3171)... Generator Loss: 1.7137
# Epoch 267/300... Discriminator Loss: 0.8150(Real: 0.4294 + Fake: 0.3856)... Generator Loss: 1.9151
# Epoch 268/300... Discriminator Loss: 0.9037(Real: 0.4666 + Fake: 0.4371)... Generator Loss: 1.8981
# Epoch 269/300... Discriminator Loss: 0.9759(Real: 0.4512 + Fake: 0.5247)... Generator Loss: 1.4413
# Epoch 270/300... Discriminator Loss: 0.7101(Real: 0.3077 + Fake: 0.4024)... Generator Loss: 1.5357
# Epoch 271/300... Discriminator Loss: 0.6577(Real: 0.3302 + Fake: 0.3275)... Generator Loss: 1.6518
# Epoch 272/300... Discriminator Loss: 0.7394(Real: 0.3473 + Fake: 0.3922)... Generator Loss: 1.7285
# Epoch 273/300... Discriminator Loss: 0.9589(Real: 0.6454 + Fake: 0.3135)... Generator Loss: 2.1891
# Epoch 274/300... Discriminator Loss: 0.6541(Real: 0.3342 + Fake: 0.3200)... Generator Loss: 1.9679
# Epoch 275/300... Discriminator Loss: 0.8408(Real: 0.3524 + Fake: 0.4884)... Generator Loss: 1.5513
# Epoch 276/300... Discriminator Loss: 0.7711(Real: 0.3580 + Fake: 0.4130)... Generator Loss: 1.6584
# Epoch 277/300... Discriminator Loss: 0.7925(Real: 0.2301 + Fake: 0.5624)... Generator Loss: 1.4618
# Epoch 278/300... Discriminator Loss: 0.7023(Real: 0.3312 + Fake: 0.3711)... Generator Loss: 1.7430
# Epoch 279/300... Discriminator Loss: 0.7465(Real: 0.4684 + Fake: 0.2781)... Generator Loss: 2.2730
# Epoch 280/300... Discriminator Loss: 0.7880(Real: 0.5006 + Fake: 0.2873)... Generator Loss: 2.3883
# Epoch 281/300... Discriminator Loss: 0.8694(Real: 0.4657 + Fake: 0.4038)... Generator Loss: 1.7822
# Epoch 282/300... Discriminator Loss: 0.7177(Real: 0.2739 + Fake: 0.4439)... Generator Loss: 1.5218
# Epoch 283/300... Discriminator Loss: 1.0261(Real: 0.7182 + Fake: 0.3080)... Generator Loss: 2.0859
# Epoch 284/300... Discriminator Loss: 0.9483(Real: 0.2709 + Fake: 0.6773)... Generator Loss: 1.2196
# Epoch 285/300... Discriminator Loss: 0.8569(Real: 0.3077 + Fake: 0.5492)... Generator Loss: 1.2807
# Epoch 286/300... Discriminator Loss: 0.8386(Real: 0.5021 + Fake: 0.3365)... Generator Loss: 1.8895
# Epoch 287/300... Discriminator Loss: 0.7555(Real: 0.3962 + Fake: 0.3593)... Generator Loss: 2.0316
# Epoch 288/300... Discriminator Loss: 0.7562(Real: 0.3470 + Fake: 0.4092)... Generator Loss: 1.7881
# Epoch 289/300... Discriminator Loss: 0.8598(Real: 0.6362 + Fake: 0.2235)... Generator Loss: 2.1229
# Epoch 290/300... Discriminator Loss: 0.8637(Real: 0.4527 + Fake: 0.4110)... Generator Loss: 1.5871
# Epoch 291/300... Discriminator Loss: 0.9463(Real: 0.4641 + Fake: 0.4822)... Generator Loss: 1.6692
# Epoch 292/300... Discriminator Loss: 0.8476(Real: 0.4045 + Fake: 0.4431)... Generator Loss: 1.5980
# Epoch 293/300... Discriminator Loss: 0.9255(Real: 0.4696 + Fake: 0.4559)... Generator Loss: 1.5795
# Epoch 294/300... Discriminator Loss: 0.8212(Real: 0.2379 + Fake: 0.5833)... Generator Loss: 1.2813
# Epoch 295/300... Discriminator Loss: 0.8452(Real: 0.5845 + Fake: 0.2606)... Generator Loss: 2.0726
# Epoch 296/300... Discriminator Loss: 0.8319(Real: 0.5335 + Fake: 0.2984)... Generator Loss: 1.7688
# Epoch 297/300... Discriminator Loss: 0.8321(Real: 0.3922 + Fake: 0.4399)... Generator Loss: 1.5715
# Epoch 298/300... Discriminator Loss: 0.8877(Real: 0.2890 + Fake: 0.5986)... Generator Loss: 1.4548
# Epoch 299/300... Discriminator Loss: 0.8256(Real: 0.2030 + Fake: 0.6226)... Generator Loss: 1.2328
# Epoch 300/300... Discriminator Loss: 0.7912(Real: 0.3659 + Fake: 0.4253)... Generator Loss: 1.5838

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator Total Loss')
plt.plot(losses.T[1], label='Discriminator Real Loss')
plt.plot(losses.T[2], label='Discriminator Fake Loss')
plt.plot(losses.T[3], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
def view_samples(epoch, samples):
    """
    epoch代表第几次迭代的图像
    samples为我们的采样结果
    """
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
_ = view_samples(-1, samples) # 显示最后一轮的outputs

# %%
# 指定要查看的轮次
epoch_idx = [0, 5, 10, 20, 40, 60, 80, 100, 150, 250] # 一共300轮，不要越界
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# WARNING:tensorflow:From /home/rhea/anaconda3/lib/python3.7/site-packages/tensorflow/python/training/saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints/generator.ckpt

# %%
_ = view_samples(0, [gen_samples])
