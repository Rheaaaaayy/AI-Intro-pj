# %%
import pandas as pd
data = pd.read_csv('BLE_RSSI_dataset/iBeacon_RSSI_Labeled.csv')
data.head()
# Out:
#   location                 date  b3001  b3002  b3003  b3004  b3005  b3006  \
# 0      O02  10-18-2016 11:15:21   -200   -200   -200   -200   -200    -78
# 1      P01  10-18-2016 11:15:19   -200   -200   -200   -200   -200    -78
# 2      P01  10-18-2016 11:15:17   -200   -200   -200   -200   -200    -77
# 3      P01  10-18-2016 11:15:15   -200   -200   -200   -200   -200    -77
# 4      P01  10-18-2016 11:15:13   -200   -200   -200   -200   -200    -77
#
#    b3007  b3008  b3009  b3010  b3011  b3012  b3013
# 0   -200   -200   -200   -200   -200   -200   -200
# 1   -200   -200   -200   -200   -200   -200   -200
# 2   -200   -200   -200   -200   -200   -200   -200
# 3   -200   -200   -200   -200   -200   -200   -200
# 4   -200   -200   -200   -200   -200   -200   -200

# %%
from sklearn.mixture import GaussianMixture

x = data[['b3001','b3002','b3003','b3004','b3005','b3006','b3007','b3008','b3009','b3010','b3011','b3012','b3013']]
gm = GaussianMixture(n_components=378).fit(x)

labels=gm.predict(x)
data['cluster_gmm'] = labels
data.sort_values('cluster_gmm')
# Out:
#      location                 date  b3001  b3002  b3003  b3004  b3005  b3006  \
# 331       L06  10-18-2016 10:56:58   -200   -200   -200   -200    -81   -200
# 950       L06   5-25-2016 10:28:37   -200   -200   -200   -200    -82   -200
# 966       N06   5-25-2016 10:27:34   -200   -200   -200   -200    -81   -200
# 956       M06   5-25-2016 10:28:16   -200   -200   -200   -200    -83   -200
# 951       L06   5-25-2016 10:28:36   -200   -200   -200   -200    -81   -200
# 332       L06  10-18-2016 10:56:56   -200   -200   -200   -200    -82   -200
# 326       M06  10-18-2016 10:57:08   -200   -200   -200   -200    -83   -200
# 1303      S02   4-20-2016 10:01:29   -200   -200   -200    -74   -200   -200
# 37        S02  10-18-2016 11:14:07   -200   -200   -200    -74   -200   -200
# 259       Q05  10-18-2016 10:59:22   -200   -200   -200    -74   -200   -200
# 1219      Q03   4-20-2016 10:16:02   -200   -200   -200    -74   -200   -200
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from time import time
from sklearn import datasets, manifold

y = data[['cluster_gmm']]

# %%
def plot_embedding(X, title=None):     
    x_min, x_max = np.min(X, 0), np.max(X, 0)
    X = (X - x_min) / (x_max - x_min)                           

    plt.figure()              
    ax = plt.subplot(111)      
    for i in range(X.shape[0]):                          
        plt.text(X[i, 0], X[i, 1], str(y['cluster_gmm'][i]),   
                 color=plt.cm.Set1((y['cluster_gmm'][i]) / 378.),         
                 fontdict={'weight': 'bold', 'size': 9})
    plt.xticks([]), plt.yticks([])
    if title is not None:
        plt.title(title)

# %%
# t-SNE embedding of the digits dataset
print("Computing t-SNE embedding")           
tsne = manifold.TSNE(n_components=2, init='pca', random_state=0)
t0 = time()
X_tsne = tsne.fit_transform(x)

plot_embedding(X_tsne)                           

plt.show()
# Out:
# Computing t-SNE embedding

# %%
x_min, x_max = np.min(X_tsne, 0), np.max(X_tsne, 0)
X = (X_tsne - x_min) / (x_max - x_min) 
plt.figure(figsize=(8,8))
plt.scatter(X[:,0], X[:,1],s=5,c=tuple(y['cluster_gmm']),cmap=plt.cm.Spectral)
plt.title('basic scatter plot ')
plt.xlabel('variables x')
plt.ylabel('variables y')

plt.legend(loc='upper right')

plt.show()
# Out:
# No handles with labels found to put in legend.
